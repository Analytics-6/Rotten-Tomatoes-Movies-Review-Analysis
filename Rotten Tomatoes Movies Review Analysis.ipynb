# %% [markdown]
# ### Reading in the data

# %%
import pandas as pd

movies = pd.read_csv(r"C:\Users\sriki\OneDrive\Desktop\Python\Maven\maven_series\maven_data_science\EDA and Data Prep\course_materials\Data//Rotten Tomatoes Movies.csv")

# %%
movies.head(3)
# Out:
#                                          movie_title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
#
#                                           movie_info  \
# 0  A teenager discovers he's the descendant of a ...
# 1  Kate has a lot on her mind. There's the ethics...
# 2  Blake Edwards' 10 stars Dudley Moore as George...
#
#                                    critics_consensus rating  \
# 0  Though it may seem like just another Harry Pot...     PG
# 1  Nicole Holofcener's newest might seem slight i...      R
# 2                                                NaN      R
#
#                                                genre          directors  \
# 0  Action & Adventure, Comedy, Drama, Science Fic...     Chris Columbus
# 1                                             Comedy  Nicole Holofcener
# ...

# %%
# Extracting the subset of data

movies = movies[['movie_title', 'rating', 'genre', 'in_theaters_date','runtime_in_minutes',
                 'tomatometer_rating', 'tomatometer_count', 'audience_rating', 'audience_count']]

movies.head(3)
# Out:
#                                          movie_title rating  \
# 0  Percy Jackson & the Olympians: The Lightning T...     PG
# 1                                        Please Give      R
# 2                                                 10      R
#
#                                                genre in_theaters_date  \
# 0  Action & Adventure, Comedy, Drama, Science Fic...       2010-02-12
# 1                                             Comedy       2010-04-30
# 2                                    Comedy, Romance       1979-10-05
#
#    runtime_in_minutes  tomatometer_rating  tomatometer_count  audience_rating  \
# 0                83.0                  49                144             53.0
# 1                90.0                  86                140             64.0
# 2               118.0                  68                 22             53.0
#
#    audience_count
# 0        254287.0
# 1         11567.0
# 2         14670.0

# %% [markdown]
# ### Exploring the data

# %%
## How many movies are in this data set? - 16638

movies.shape
# Out:
# (16638, 9)

# %%
## Filtering the data to only include movies that came out in 2010 or later.

# %%
movies["in_theaters_date"]
# Out:
# 0        2010-02-12
# 1        2010-04-30
# 2        1979-10-05
# 3        1957-04-13
# 4        1954-01-01
#             ...
# 16633    1981-10-02
# 16634    2016-03-04
# 16635    1964-12-17
# 16636    1964-06-17
# 16637    1979-12-14
# Name: in_theaters_date, Length: 16638, dtype: object

# %%
# Checking column datatypes

movies.dtypes
# Out:
# movie_title            object
# rating                 object
# genre                  object
# in_theaters_date       object
# runtime_in_minutes    float64
# tomatometer_rating      int64
# tomatometer_count       int64
# audience_rating       float64
# audience_count        float64
# dtype: object

# %%
# Converting datatype of column - in_theaters_date

movies["in_theaters_date"] = pd.to_datetime(movies["in_theaters_date"])

movies.dtypes
# Out:
# movie_title                   object
# rating                        object
# genre                         object
# in_theaters_date      datetime64[ns]
# runtime_in_minutes           float64
# tomatometer_rating             int64
# tomatometer_count              int64
# audience_rating              float64
# audience_count               float64
# dtype: object

# %%
# Extracting year from column

movies["in_theaters_date"].dt.year
# Out:
# 0        2010.0
# 1        2010.0
# 2        1979.0
# 3        1957.0
# 4        1954.0
#           ...
# 16633    1981.0
# 16634    2016.0
# 16635    1964.0
# 16636    1964.0
# 16637    1979.0
# Name: in_theaters_date, Length: 16638, dtype: float64

# %%
movies["in_theaters_date"].dt.year>=2010
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 16633    False
# 16634     True
# 16635    False
# 16636    False
# 16637    False
# Name: in_theaters_date, Length: 16638, dtype: bool

# %%
movies[movies["in_theaters_date"].dt.year>=2010]
# Out:
#                                              movie_title rating  \
# 0      Percy Jackson & the Olympians: The Lightning T...     PG
# 1                                            Please Give      R
# 97                               Fireflies in the Garden      R
# 130                                   The Oxford Murders      R
# 155                                               Priest  PG-13
# ...                                                  ...    ...
# 16623                                         Zombeavers      R
# 16628                                                Zoo     PG
# 16629                                          Zookeeper     PG
# 16631                                        Zoolander 2  PG-13
# 16634                                           Zootopia     PG
#
#                                                    genre in_theaters_date  \
# 0      Action & Adventure, Comedy, Drama, Science Fic...       2010-02-12
# ...

# %%
# Creating a new dataframe with extracted data

movies = movies[movies["in_theaters_date"].dt.year>=2010]

movies.head(3)
# Out:
#                                           movie_title rating  \
# 0   Percy Jackson & the Olympians: The Lightning T...     PG
# 1                                         Please Give      R
# 97                            Fireflies in the Garden      R
#
#                                                 genre in_theaters_date  \
# 0   Action & Adventure, Comedy, Drama, Science Fic...       2010-02-12
# 1                                              Comedy       2010-04-30
# 97                                              Drama       2011-10-14
#
#     runtime_in_minutes  tomatometer_rating  tomatometer_count  \
# 0                 83.0                  49                144
# 1                 90.0                  86                140
# 97                98.0                  22                 54
#
#     audience_rating  audience_count
# 0              53.0        254287.0
# 1              64.0         11567.0
# 97             45.0         45150.0

# %%
## How many movies are in this new data set? - 6053

movies.shape
# Out:
# (6053, 9)

# %%
## Finding the highest rated movies according to critics (tomatometer_rating) and the general audience (audience_rating).

movies.sort_values("tomatometer_rating", ascending=False).head(3)
# Out:
#                                   movie_title rating  \
# 3093  Batman: The Dark Knight Returns, Part 1  PG-13
# 8500                             King Georges     NR
# 8495                         King Charles III     NR
#
#                               genre in_theaters_date  runtime_in_minutes  \
# 3093  Action & Adventure, Animation       2012-01-01               134.0
# 8500                    Documentary       2016-02-26                78.0
# 8495                          Drama       2017-05-14                88.0
#
#       tomatometer_rating  tomatometer_count  audience_rating  audience_count
# 3093                 100                  5             93.0          8482.0
# 8500                 100                  9             54.0           240.0
# 8495                 100                  9             48.0            65.0

# %%
## Finding the highest rated movies according to the general audience (audience_rating)

movies.sort_values("audience_rating", ascending=False).head(3)
# Out:
#              movie_title rating                                 genre  \
# 14566  The Miners' Hymns     NR  Documentary, Drama, Special Interest
# 9051     Little Monsters      R                        Comedy, Horror
# 7137               Haunt      R            Horror, Mystery & Suspense
#
#       in_theaters_date  runtime_in_minutes  tomatometer_rating  \
# 14566       2012-02-08                52.0                 100
# 9051        2019-10-08                94.0                  83
# 7137        2019-09-13                92.0                  68
#
#        tomatometer_count  audience_rating  audience_count
# 14566                 10            100.0           148.0
# 9051                  94            100.0             9.0
# 7137                  38            100.0             7.0

# %%
## These top movies seem to have very few critics and audience members writing the reviews. 
## We want to look at only the most popular movies. 
## Filtering the movies data set to only include movies that have 100k+ audience ratings. 

movies_popular = movies[movies["audience_count"]>100000]

movies_popular.head(3)
# Out:
#                                            movie_title rating  \
# 0    Percy Jackson & the Olympians: The Lightning T...     PG
# 248                                        Tron Legacy     PG
# 265                                      The Last Song     PG
#
#                                                  genre in_theaters_date  \
# 0    Action & Adventure, Comedy, Drama, Science Fic...       2010-02-12
# 248      Action & Adventure, Science Fiction & Fantasy       2010-12-17
# 265                      Drama, Kids & Family, Romance       2010-03-31
#
#      runtime_in_minutes  tomatometer_rating  tomatometer_count  \
# 0                  83.0                  49                144
# 248               125.0                  51                239
# 265               107.0                  20                118
#
#      audience_rating  audience_count
# 0               53.0        254287.0
# 248             63.0        171385.0
# 265             66.0        160777.0

# %%
## How many movies are in this data set? - 316

movies_popular.shape
# Out:
# (316, 9)

# %%
# Finding the highest rated popular movies according to critics (tomatometer_rating)

movies_popular.sort_values("tomatometer_rating", ascending=False).head(3)
# Out:
#                     movie_title rating  \
# 7558   How to Train Your Dragon     PG
# 15416               Toy Story 3      G
# 7925                 Inside Out     PG
#
#                                                    genre in_theaters_date  \
# 7558   Animation, Kids & Family, Science Fiction & Fa...       2010-03-26
# 15416                   Animation, Comedy, Kids & Family       2010-06-18
# 7925                            Animation, Kids & Family       2015-06-19
#
#        runtime_in_minutes  tomatometer_rating  tomatometer_count  \
# 7558                 98.0                  99                208
# 15416               103.0                  98                305
# 7925                 94.0                  98                357
#
#        audience_rating  audience_count
# 7558              91.0        312342.0
# 15416             89.0        606931.0
# 7925              89.0        136125.0

# %%
# Finding the highest rated popular movies according the general audience (audience_rating)

movies_popular.sort_values("audience_rating", ascending=False).head(3)
# Out:
#                                movie_title rating  \
# 16634                             Zootopia     PG
# 6950               Guardians of the Galaxy  PG-13
# 4077   Captain America: The Winter Soldier  PG-13
#
#                                                genre in_theaters_date  \
# 16634          Action & Adventure, Animation, Comedy       2016-03-04
# 6950   Action & Adventure, Science Fiction & Fantasy       2014-08-01
# 4077   Action & Adventure, Science Fiction & Fantasy       2014-04-04
#
#        runtime_in_minutes  tomatometer_rating  tomatometer_count  \
# 16634               108.0                  97                279
# 6950                121.0                  91                316
# 4077                136.0                  90                292
#
#        audience_rating  audience_count
# 16634             92.0        100946.0
# 6950              92.0        254717.0
# 4077              92.0        281524.0

# %%
## A lot of these popular movies seem to have a PG or PG-13 rating. 

## How many movies fall under each type of rating?

movies_popular["rating"].value_counts()
# Out:
# PG-13    160
# R        100
# PG        51
# G          5
# Name: rating, dtype: int64

# %%
## Using this popular movies data set going forward in this notebook.

movies_popular.head(3)
# Out:
#                                            movie_title rating  \
# 0    Percy Jackson & the Olympians: The Lightning T...     PG
# 248                                        Tron Legacy     PG
# 265                                      The Last Song     PG
#
#                                                  genre in_theaters_date  \
# 0    Action & Adventure, Comedy, Drama, Science Fic...       2010-02-12
# 248      Action & Adventure, Science Fiction & Fantasy       2010-12-17
# 265                      Drama, Kids & Family, Romance       2010-03-31
#
#      runtime_in_minutes  tomatometer_rating  tomatometer_count  \
# 0                  83.0                  49                144
# 248               125.0                  51                239
# 265               107.0                  20                118
#
#      audience_rating  audience_count
# 0               53.0        254287.0
# 248             63.0        171385.0
# 265             66.0        160777.0

# %%
## What is the average audience rating for each movie rating type?

movies_popular.groupby("rating")["audience_rating"].mean()
# Out:
# rating
# G        66.200000
# PG       66.823529
# PG-13    67.293750
# R        63.010000
# Name: audience_rating, dtype: float64

# %%
## Which rating type is most highly rated?

movies_popular.groupby("rating")["audience_rating"].mean().sort_values(ascending=False).head(1)
# Out:
# rating
# PG-13    67.29375
# Name: audience_rating, dtype: float64

# %% [markdown]
# ### Creating New Columns

# %%
import numpy as np

np.where
# Out:
# <function numpy.where>

# %%
## Create a column in the DataFrame called 'Animation' and return a 1 if a movie is an 'Animation' movie and 0 otherwise

movies_popular["Animation"] = np.where(movies_popular["genre"].str.contains("Animation"),1,0)
# Out:
# C:\Users\sriki\AppData\Local\Temp\ipykernel_18964\2061111203.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_popular["Animation"] = np.where(movies_popular["genre"].str.contains("Animation"),1,0)

# %%
# copy the movie to avoid a warning

movies_popular = movies_popular = movies[movies["audience_count"]>100000].copy()

# %%
movies_popular["Animation"] = np.where(movies_popular["genre"].str.contains("Animation"),1,0)

# %%
## Doing the same for Action & Adventure and Comedy

movies_popular["Action & Adventure"] = np.where(movies_popular["genre"].str.contains("Action & Adventure"),1,0)

movies_popular["Comedy"] = np.where(movies_popular["genre"].str.contains("Comedy"),1,0)

# %%
# Dataset with 3 new columns

movies_popular.head(3)
# Out:
#                                            movie_title rating  \
# 0    Percy Jackson & the Olympians: The Lightning T...     PG
# 248                                        Tron Legacy     PG
# 265                                      The Last Song     PG
#
#                                                  genre in_theaters_date  \
# 0    Action & Adventure, Comedy, Drama, Science Fic...       2010-02-12
# 248      Action & Adventure, Science Fiction & Fantasy       2010-12-17
# 265                      Drama, Kids & Family, Romance       2010-03-31
#
#      runtime_in_minutes  tomatometer_rating  tomatometer_count  \
# 0                  83.0                  49                144
# 248               125.0                  51                239
# 265               107.0                  20                118
#
#      audience_rating  audience_count  Animation  Action & Adventure  Comedy
# 0               53.0        254287.0          0                   1       1
# ...

# %%
## Creating a table where each row is a rating, each column is a genre
## Each value is the number of movies of that particular rating and genre

movies_popular.groupby("rating")[["Animation", "Action & Adventure", "Comedy"]].sum()
# Out:
#         Animation  Action & Adventure  Comedy
# rating
# G               5                   3       5
# PG             26                  27      29
# PG-13           0                 102      35
# R               0                  41      35

# %%
## Insights

# There are almost more or less equal number of movies in all 3 genres for PG rating
# No Animation movies for PG-13 and R ratings
# Action and Adventure movies are highly popular when it comes to PG-13 rating

# %%
# Finding the average critic and audience rating for an Animation movie vs a non-Animation movie. 

movies_popular.groupby("Animation")[["tomatometer_rating", "audience_rating"]].mean()
# Out:
#            tomatometer_rating  audience_rating
# Animation
# 0                   58.340351        64.831579
# 1                   75.258065        75.161290

# %%
# Doing the same for Action & Adventure and Comedy

movies_popular.groupby("Action & Adventure")[["tomatometer_rating", "audience_rating"]].mean()
# Out:
#                     tomatometer_rating  audience_rating
# Action & Adventure
# 0                            59.111888        65.391608
# 1                            60.734104        66.219653

# %%
movies_popular.groupby("Comedy")[["tomatometer_rating", "audience_rating"]].mean()
# Out:
#         tomatometer_rating  audience_rating
# Comedy
# 0                62.169811        67.353774
# 1                55.576923        62.769231

# %%
## Insights

# Both critics and the general audience love animated movies
# General audience likes action movies more than critics
# Comedies have lower ratings than other genres

# %% [markdown]
# ### Visualizing the data

# %%
import seaborn as sns

# %%
sns.pairplot(movies_popular);

# %%
## Too many charts to intepret so excluding the three new columns for visualization

movies_popular.iloc[:,:-3].head(3)
# Out:
#                                            movie_title rating  \
# 0    Percy Jackson & the Olympians: The Lightning T...     PG
# 248                                        Tron Legacy     PG
# 265                                      The Last Song     PG
#
#                                                  genre in_theaters_date  \
# 0    Action & Adventure, Comedy, Drama, Science Fic...       2010-02-12
# 248      Action & Adventure, Science Fiction & Fantasy       2010-12-17
# 265                      Drama, Kids & Family, Romance       2010-03-31
#
#      runtime_in_minutes  tomatometer_rating  tomatometer_count  \
# 0                  83.0                  49                144
# 248               125.0                  51                239
# 265               107.0                  20                118
#
#      audience_rating  audience_count
# 0               53.0        254287.0
# 248             63.0        171385.0
# 265             66.0        160777.0

# %%
sns.pairplot(movies_popular.iloc[:,:-3]);

# %%
sns.pairplot(movies_popular.iloc[:,:-3], height=2);

# %%
## Insights

# critics gave harsher reviews -- there are quite a few low ratings in the tomatometer histogram
# the run time of movies seems to be correlated with the number of critic ratings
# the most popular movie is Shutter Island with lots of audience ratings and not as many critic ratings --
# this is so extreme that it could potentially be an outlier / error

# %%
movies_popular[movies_popular["audience_count"]>100000]
# Out:
#                                              movie_title rating  \
# 0      Percy Jackson & the Olympians: The Lightning T...     PG
# 248                                          Tron Legacy     PG
# 265                                        The Last Song     PG
# 274                                             Repo Men      R
# 284                                            Predators      R
# ...                                                  ...    ...
# 16492                         X-Men: Days of Future Past  PG-13
# 16493                                 X-Men: First Class  PG-13
# 16591                                    Youth in Revolt      R
# 16612                                   Zero Dark Thirty      R
# 16634                                           Zootopia     PG
#
#                                                    genre in_theaters_date  \
# 0      Action & Adventure, Comedy, Drama, Science Fic...       2010-02-12
# ...
